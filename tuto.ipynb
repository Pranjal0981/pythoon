# %%
import pandas as pd
import numpy as np
data=pd.read_csv('read.csv')
df=data.head(10)
df.describe()
data['Cost']
# Out:
# 0        392.0
# 1        392.0
# 2        392.0
# 3       1062.0
# 4       1569.0
#          ...
# 4363     402.0
# 4364    1200.0
# 4365     528.0
# 4366     750.0
# 4367     336.0
# Name: Cost, Length: 4368, dtype: float64

# %%
filtered_df = data[data['School'] == 'Montgomery College Rockville Campus']
filtered_df
# Out:
#                            Department                                Major  \
# 0                              Police                Business/Admin./Mgmt.
# 1                              Police                Business/Admin./Mgmt.
# 2                              Police                Business/Admin./Mgmt.
# 6                              Police                Business/Admin./Mgmt.
# 50                     Transportation                 Agricultural General
# ...                               ...                                  ...
# 4328      Correction & Rehabilitation                Public Administration
# 4334                   Transportation  Civil and Environmental Engineering
# 4350  Community Use Public Facilities                Accounting (Business)
# 4359  Community Use Public Facilities                Accounting (Business)
# 4367                   Transportation  Civil and Environmental Engineering
#
#                  Degree                               School  \
# ...

# %%
sorted_df = data.sort_values(by='Cost')
sorted_df
# Out:
#                    Department                    Major  \
# 3232     Fire/Rescue Services              Other/Misc.
# 462      Fire/Rescue Services  Health & Human Services
# 608      Fire/Rescue Services                     HVAC
# 1504     Fire/Rescue Services     Emergency Management
# 2198         State's Attorney        Paralegal Studies
# ...                       ...                      ...
# 4003  Health & Human Services    Business/Admin./Mgmt.
# 533                    Police                      NaN
# 4254                  Sheriff               Psychology
# 4354      Investment Trustees                      NaN
# 4280  Health & Human Services               Psychology
#
#                         Degree                                       School  \
# 3232  Masters (MA/MS/MPH/etc.)                         Stevenson University
# 462          Bachelors (BA/BS)        University of Maryland - College Park
# ...

# %%
grouped_df = df.groupby('Department')['Cost'].mean()
grouped_df
# Out:
# Department
# County Attorney               0.00
# Finance                     870.00
# Health & Human Services    1188.75
# Police                      392.00
# Name: Cost, dtype: float64

# %%
filtered_df = data[(data['School'] == 'Montgomery College Rockville Campus') & (data['Cost'] > 300)]
filtered_df
# Out:
#                            Department                                Major  \
# 0                              Police                Business/Admin./Mgmt.
# 1                              Police                Business/Admin./Mgmt.
# 2                              Police                Business/Admin./Mgmt.
# 6                              Police                Business/Admin./Mgmt.
# 53            Health & Human Services                Business/Admin./Mgmt.
# ...                               ...                                  ...
# 4328      Correction & Rehabilitation                Public Administration
# 4334                   Transportation  Civil and Environmental Engineering
# 4350  Community Use Public Facilities                Accounting (Business)
# 4359  Community Use Public Facilities                Accounting (Business)
# 4367                   Transportation  Civil and Environmental Engineering
#
#                  Degree                               School  \
# ...

# %%
df['Discounted Price']= df['Cost'] * 100
df
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8224\4195625935.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Discounted Price']= df['Cost'] * 100
#                 Department                    Major                    Degree  \
# 0                   Police    Business/Admin./Mgmt.                        AA
# 1                   Police    Business/Admin./Mgmt.                        AA
# 2                   Police    Business/Admin./Mgmt.                        AA
# 3  Health & Human Services    Business/Admin./Mgmt.  Masters (MA/MS/MPH/etc.)
# 4  Health & Human Services              Other/Misc.  Masters (MA/MS/MPH/etc.)
# 5                  Finance    Accounting (Business)  Masters (MA/MS/MPH/etc.)
# ...

# %%
df.rename(columns={'Cost': 'Course Cost'}, inplace=True)
df
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_8224\4289433719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns={'Cost': 'Course Cost'}, inplace=True)
#                 Department                    Major                    Degree  \
# 0                   Police    Business/Admin./Mgmt.                        AA
# 1                   Police    Business/Admin./Mgmt.                        AA
# 2                   Police    Business/Admin./Mgmt.                        AA
# 3  Health & Human Services    Business/Admin./Mgmt.  Masters (MA/MS/MPH/etc.)
# 4  Health & Human Services              Other/Misc.  Masters (MA/MS/MPH/etc.)
# 5                  Finance    Accounting (Business)  Masters (MA/MS/MPH/etc.)
# ...

# %%
#df.drop(columns=['Degree'], inplace=True)
df
# Out:
#                 Department                    Major                    Degree  \
# 0                   Police    Business/Admin./Mgmt.                        AA
# 1                   Police    Business/Admin./Mgmt.                        AA
# 2                   Police    Business/Admin./Mgmt.                        AA
# 3  Health & Human Services    Business/Admin./Mgmt.  Masters (MA/MS/MPH/etc.)
# 4  Health & Human Services              Other/Misc.  Masters (MA/MS/MPH/etc.)
# 5                  Finance    Accounting (Business)  Masters (MA/MS/MPH/etc.)
# 6                   Police    Business/Admin./Mgmt.                        AA
# 7  Health & Human Services              Pre-Nursing                        AA
# 8          County Attorney  Health & Human Services         Bachelors (BA/BS)
# 9  Health & Human Services               Not Listed  Masters (MA/MS/MPH/etc.)
#
#                                         School  \
# 0          Montgomery College Rockville Campus
# ...

# %%
df_filled = data.fillna({'Cost': 0})
df_filled  # This will show the DataFrame with missing values filled
df
# Out:
#                 Department                    Major                    Degree  \
# 0                   Police    Business/Admin./Mgmt.                        AA
# 1                   Police    Business/Admin./Mgmt.                        AA
# 2                   Police    Business/Admin./Mgmt.                        AA
# 3  Health & Human Services    Business/Admin./Mgmt.  Masters (MA/MS/MPH/etc.)
# 4  Health & Human Services              Other/Misc.  Masters (MA/MS/MPH/etc.)
# 5                  Finance    Accounting (Business)  Masters (MA/MS/MPH/etc.)
# 6                   Police    Business/Admin./Mgmt.                        AA
# 7  Health & Human Services              Pre-Nursing                        AA
# 8          County Attorney  Health & Human Services         Bachelors (BA/BS)
# 9  Health & Human Services               Not Listed  Masters (MA/MS/MPH/etc.)
#
#                                         School  \
# 0          Montgomery College Rockville Campus
# ...

# %%
nan_df = df.isna()
nan_df
#.isna btata  h ki nan value kha pr he
# Out:
#    Department  Major  Degree  School  Course Title  Course Description  \
# 0       False  False   False   False         False               False
# 1       False  False   False   False         False               False
# 2       False  False   False   False         False               False
# 3       False  False   False   False         False               False
# 4       False  False   False   False         False               False
# 5       False  False   False   False         False               False
# 6       False  False   False   False         False               False
# 7       False  False   False   False         False               False
# 8       False  False   False   False         False               False
# 9       False  False   False   False         False               False
#
#    Course Cost  Discounted Price
# 0        False             False
# 1        False             False
# 2        False             False
# 3        False             False
# ...

# %%
# Counting NaN values in each column
nan_count = df.isna().sum()

nan_count
# Out:
# Department            0
# Major                 0
# Degree                0
# School                0
# Course Title          0
# Course Description    0
# Course Cost           0
# Discounted Price      0
# dtype: int64
